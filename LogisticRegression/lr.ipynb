# %%
# plot logistic sigmoid funciton

import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-5, 5, 11)
Y = 1 / (1+np.exp(-X))

plt.plot(X, Y)
plt.show()

# %%
# plot logistic sigmoid funciton

import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-100, 100, 201)
Y = 1 / (1+np.exp(-X))

plt.plot(X, Y)
plt.show()
